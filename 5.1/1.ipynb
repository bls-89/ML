# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# Загрузим датасет

# %%
data = pd.read_csv('dataset_0.csv')

# %% [markdown]
# Построим тепловую карту корреляции чтобы понять какие данные являются случайным шумом - данные никоим обращом не коррелирующие ни с целевым признаком ни с фичами.

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %% [markdown]
# по графику я бы убрал feature 3,4,13,17,20 (корреляция 0 так как цвет графика красный)

# %%
data.drop (['feature_3','feature_4','feature_13','feature_17','feature_20'], axis= 1 , inplace= True )

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %% [markdown]
# теперь нулевая корреляция отсутствует - шумоff нет)
